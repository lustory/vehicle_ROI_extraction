# %% [raw]
# %run utils.ipynb
#
# random.seed(0)

# %% [raw]
# image_dir = "./files/4_split_400/"

# %% [raw]
# image_paths = get_all_images(image_dir, shuffle = False)

# %% [raw]
# num = 2150
# image_path = image_paths[num]

# %% [markdown]
# image_name = "海马--海马--福美来--2012--2013/福美来VS__福美来VS__2012款1.6L手动旗舰版__0f9b6d8aedea65cb62906c5e560111ac2ac2e6f9.jpg"
# image_path = os.path.join(image_dir, image_name)

# %% [markdown]
# ## roi plan 1

# %% [raw]
# lp_coords, roi_coords, roi = roi_extraction_1(image_path)
# lp_x1, lp_y1, lp_x2, lp_y2 = lp_coords
# roi_x1, roi_y1, roi_x2, roi_y2 = roi_coords

# %%
image = imread(image_path, width = 256, height = 128)

# %% [raw]
# plt.figure(figsize=(16, 6.5))
#
# # plt.title("ROI plan 1")
# plt.imshow(image)
# plt.gca().add_patch(plt.Rectangle(xy = (lp_x1, lp_y1),
#                                   width = lp_x2 - lp_x1, height = lp_y2 - lp_y1, edgecolor = 'red', fill = False, linewidth = 2))
#
# plt.gca().add_patch(plt.Rectangle(xy = (roi_x1, roi_y1),
#                                   width = roi_x2 - roi_x1, height = roi_y2 - roi_y1, edgecolor = 'red', fill = False, linewidth = 2))
#
# plt.plot()
# plt.axis("off");

# %% [markdown]
# ## roi plan 2

# %% [raw]
# lp_coords, roi_coords, roi = roi_extraction_2(image_path)
# lp_x1, lp_y1, lp_x2, lp_y2 = lp_coords
# roi_x1, roi_y1, roi_x2, roi_y2 = roi_coords

# %% [raw]
# plt.figure(figsize=(16, 6.5))
#
# # plt.title("ROI plan 2")
# plt.imshow(image)
# plt.gca().add_patch(plt.Rectangle(xy = (lp_x1, lp_y1),
#                                   width = lp_x2 - lp_x1, height = lp_y2 - lp_y1, edgecolor = 'red', fill = False, linewidth = 2))
#
# plt.gca().add_patch(plt.Rectangle(xy = (roi_x1, roi_y1),
#                                   width = roi_x2 - roi_x1, height = roi_y2 - roi_y1, edgecolor = 'red', fill = False, linewidth = 2))
#
# plt.plot()
# plt.axis("off");

# %% [markdown]
# ## roi plan ours

# %% [raw]
# lp_coords, roi_coords, roi = roi_extraction_with_hood(image_path)
# lp_x1, lp_y1, lp_x2, lp_y2 = lp_coords
# roi_x1, roi_y1, roi_x2, roi_y2 = roi_coords

# %% [raw]
# plt.figure(figsize=(16, 6.5))
#
# # plt.title("ROI plan 2")
# plt.imshow(image)
# plt.gca().add_patch(plt.Rectangle(xy = (lp_x1, lp_y1),
#                                   width = lp_x2 - lp_x1, height = lp_y2 - lp_y1, edgecolor = 'red', fill = False, linewidth = 2))
#
# plt.gca().add_patch(plt.Rectangle(xy = (roi_x1, roi_y1),
#                                   width = roi_x2 - roi_x1, height = roi_y2 - roi_y1, edgecolor = 'red', fill = False, linewidth = 2))
#
# plt.plot()
# plt.axis("off");

# %% [markdown]
# ## overall compare

# %%
plt.figure(figsize=(16, 6.5))
plt.imshow(image)

for method, color in zip([roi_extraction_1, roi_extraction_2, roi_extraction_with_hood], ["blue", "red", "yellow"]):
    lp_coords, roi_coords, roi = method(image_path)
    lp_x1, lp_y1, lp_x2, lp_y2 = lp_coords
    roi_x1, roi_y1, roi_x2, roi_y2 = roi_coords
    
    plt.gca().add_patch(plt.Rectangle(xy = (roi_x1, roi_y1), 
                                  width = roi_x2 - roi_x1, height = roi_y2 - roi_y1, 
                                  edgecolor = color, fill = False, linewidth = 3, linestyle = "--"))
plt.plot();
plt.axis("off");
